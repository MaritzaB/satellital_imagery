# %% [markdown]
# # Variables en Python

# %% [markdown]
# ***
# ## Se tienen 240 cajas con 25 bolsas de café cada una. Si cada bolsa pesa 0.62 kg, ¿cuál es el peso del café?
# ***

# %% [markdown]
# # Funciones
# ### Una función en Python (y en cualquier otro lenguaje de programación) es un bloque de líneas de código o un conjunto de instrucciones cuya finalidad es realizar una tarea específica. Puede reutilizarse a voluntad para repetir dicha tarea.

# %% [markdown]
# ## Como crear funciones?
# ![como crera funciones en python.jpg](attachment:8ef90ce8-985f-4c19-b5c3-548ab04cb276.jpg)
